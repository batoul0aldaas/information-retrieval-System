# %% [markdown]
# # Dataset Exploration & Loading
# Use this notebook to explore and load IR datasets.

# %%
import ir_datasets

# List some available datasets
# Visit https://ir-datasets.com for full list
print('ir-datasets version:', ir_datasets.__version__)

# %%
# Example: Load MS MARCO passage dataset
# dataset = ir_datasets.load('msmarco-passage')
# for doc in dataset.docs_iter():
#     print(doc.doc_id, doc.text[:100])
#     break
print('Uncomment and run to load your chosen dataset')

# %%
import sys
sys.path.append('..')
from services.preprocessing_service.preprocessor import preprocess

test_text = 'The quick brown fox jumps over the lazy dog'
tokens = preprocess(test_text)
print('Original:', test_text)
print('Processed:', tokens)
